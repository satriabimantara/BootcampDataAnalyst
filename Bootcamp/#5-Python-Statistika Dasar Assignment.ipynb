# %% [markdown]
# # Data Pelanggaran Lalu Lintas

# %%
import pandas as pd

# %%
data = pd.read_csv('dataset/Data-Penindakan-Pelanggaran-Lalu-Lintas.csv')

# %%
data
# Out:
#        bulan                   wilayah  bap_tilang  stop_operasi  bap_polisi  \
# 0    Januari             Bidang Dalops          44           139           0
# 1    Januari    Sudinhub Jakarta Pusat          47             2          52
# 2    Januari    Sudinhub Jakarta Utara         166            27           0
# 3    Januari  Sudinhub Jakarta Selatan          44             1           0
# 4    Januari    Sudinhub Jakarta Barat         184            70           0
# 5    Januari    Sudinhub Jakarta Timur         191           141           0
# 6   Februari             Bidang Dalops          37           143           0
# 7   Februari    Sudinhub Jakarta Pusat          48             7          42
# 8   Februari    Sudinhub Jakarta Utara         251            27          31
# 9   Februari  Sudinhub Jakarta Selatan         129            12           0
# 10  Februari    Sudinhub Jakarta Barat         229            60           0
# ...

# %%
hasil_seleksi_dataframe = data.groupby('bulan').mean()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16120\3230116828.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hasil_seleksi_dataframe = data.groupby('bulan').mean()

# %%
hasil_seleksi_dataframe
# Out:
#           bap_tilang  stop_operasi  bap_polisi  stop_operasi_polisi  \
# bulan
# April     237.500000     67.166667    2.000000                  0.0
# Februari  161.666667     65.833333   12.166667                  0.0
# Januari   112.666667     63.333333    8.666667                  0.0
# Juli       90.500000     35.333333    5.333333                  0.0
# Juni      214.166667     64.333333    9.166667                  0.0
# Maret     247.166667     88.500000    0.000000                  0.0
# Mei       128.666667     54.333333    3.000000                  0.0
#
#           penderekan  ocp_roda_dua  ocp_roda_empat  angkut_motor
# bulan
# April     207.833333     87.000000       12.000000     19.500000
# Februari  204.000000    143.166667       22.666667     23.833333
# Januari   138.500000     48.166667       15.833333     16.166667
# Juli       44.500000     51.000000        1.500000      3.166667
# Juni      160.500000    192.000000       11.166667     69.000000
# ...

# %%
hasil_seleksi_dataframe.loc['Januari', 'bap_tilang']
# Out:
# 112.66666666666667

# %%
hasil_seleksi_dataframe.iloc[2,0]
# Out:
# 112.66666666666667
